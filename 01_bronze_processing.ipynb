# %%
# 01_bronze_processing: Raw sensor data ingestion

import dlt

# -----------------------------
# Bronze tables – one per sensor type
# -----------------------------

@dlt.table(
    name="bronze_temperature",
    comment="Raw temperature sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_temperature():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/temperature")
    )

@dlt.table(
    name="bronze_vibration",
    comment="Raw vibration sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_vibration():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/vibration")
    )

@dlt.table(
    name="bronze_power",
    comment="Raw power sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_power():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/power")
    )

@dlt.table(
    name="bronze_pressure",
    comment="Raw pressure sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_pressure():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/pressure")
    )

@dlt.table(
    name="bronze_flow_rate",
    comment="Raw flow_rate sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_flow_rate():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/flow_rate")
    )

@dlt.table(
    name="bronze_rpm",
    comment="Raw rpm sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_rpm():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/rpm")
    )

@dlt.table(
    name="bronze_speed",
    comment="Raw speed sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_speed():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/speed")
    )

@dlt.table(
    name="bronze_current",
    comment="Raw current sensor readings",
    table_properties={
        "quality": "bronze",
        "pipelines.autoOptimize.managed": "true"
    }
)
def bronze_current():
    return (
        spark.readStream
             .format("delta")
             .option("ignoreDeletes", "true")
             .option("ignoreChanges", "true")
             .load("/Volumes/industrial-iot/00_landing/streaming/current")
    )
